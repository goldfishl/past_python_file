# %% [markdown]
# > ## 程序案例：
# >
# >  <font size=3>  为了方便管理班级学生的成绩，我们需要开发一个简便的系统来统计学生成绩的信息。</font>
# >
# >  <font size=3>  此项目主要为简单的python的项目，所以不涉及到可视化的操作界面，只需要简单的输入输出函数来实现项目。</font>
#
# ---
#
# > ## 该项目需要的功能：
# >
# >  <font size=3>  1. 使用数据结构存储学生成绩</font>
# >
# >  <font size=3>  2. 调用函数展示学生成绩</font>
# >
# >  <font size=3>  3. 调用函数图形可视化学生成绩</font>
# >
# >  <font size=3>  4. 调用函数存储新的学生</font>
# >
# >  <font size=3>  5. 调用函数插入、修改、删除学生成绩</font>
# >
# > ## 所用到的技术：
# >
# >  <font size=3>python、pyecharts</font>
#
# ---

# %% [markdown]
# > ## 第一部分（主体程序体的搭建）
# > ### 1、clear( )函数
# > <font size=3>函数：clear( )</font>
# >
# > <font size=3>作用：清空控制台或输出的内容</font>
# >
# > <font size=3>使用方式：</font>
# >
# > ```python
# > from IPython.display import clear_output as clear
# > clear()
# > ```
# >
# > <font size=3>示例：</font>
# > ```python
# > from IPython.display import clear_output as clear
# > print('测试显示打印')
# > y = input('是否清空界面(输入\'是\'或者\'否\')：')
# > if y == '是':
# >     clear()
# > print('一定会显示的内容')
# > ```

# %%
# 上述代码测试位置（可以将上述代码拷贝到这里测试）

# %% [markdown]
# > ### 2、使用死循环搭建主体程序体
# >
# > <font size=3>解析：因为我们的管理系统需要不停的判断输入，所以在这里使用死循环来接收输入。</font>
# >
# > <font size=3>使用方式：</font>
# >
# > ```python
# > while True:
# >     循环体
# > ```
# >
# > <font size=3>代码提示：</font>
# > ```python
# > from IPython.display import clear_output as clear
# > while True:
# >     print('1.添加一个学生的信息')
# >     print('2.删除一个学生的信息')
# >     print('3.更新一个学生的信息')
# >     print('4.返回指定班某科的平均值')
# >     print('5.输出两个班级三科总分的平均值柱状图')
# >     choose = （此处补充input函数，传入参数为：'请输入1到5的一个数字'）
# >     if choose == '1':
# >         pass
# >     elif choose == '2':
# >         pass
# >     （我们会判断输入分别为1、2、3、4、5时程序的运行，此处将剩余用户输入判断完成）
# >     else:
# >         print('输入错误，返回主界面')
# >     if(require() == 0):
# >             break
# > ```
# > <font size=3>作答：</font>

# %%
# 第2题作答部分
# 当此处作答完成后，点击运行进行测试。
# 注意！：若需要停止运行，点击运行旁边的 中断内核 按键
from IPython.display import clear_output as clear

# require函数不能修改
def require():
    re = input('是否继续操作？（输入‘是’为继续操作，其他为退出系统）')
    if re == '是':
        clear()
    else:
        return 0
    

# 作答部分
y = input('是否进入系统（输入‘是’为继续操作，其他为退出系统）：')
if y == '是':
    while True:
        print('1.添加一个学生的信息')
        print('2.删除一个学生的信息')
        print('3.更新一个学生的信息')
        print('4.返回指定班某科的平均值')
        print('5.输出两个班级三科总分的平均值柱状图')
        choose = （此处补充input函数，传入参数为：'请输入1到5的一个数字'）
        if choose == '1':
            pass
        elif choose == '2':
            pass
        （我们会判断输入分别为1、2、3、4、5时程序的运行，此处将剩余用户输入判断完成）
        else:
            print('输入错误，返回主界面')
        if(require() == 0):
                break

clear()
print('退出系统')

# %% [markdown]
# > ### 3、创建学生信息表
# >
# > <font size=3>解析：我们的系统中，已存在两个班部分同学的考试成绩以及信息，在这里，我们需要将信息导入</font>
# >
# > <font size=3>学生个人信息存储方式：字典（dict）</font>
# > <font size=3>学生班级信息存储方式：字典（dict）</font>
# >
# > **<font size=4>班级与学生之间对应关系：</font>**
#
# | 一班 | 二班 |
# | ------ | ------ |
# | 一班所有学生 | 二班所有学生 |
# > **<font size=4>代码：</font>**
# > ```python
# > info = {
# >     '一班': {}
# >     '二班': {}
# > }
# > ```
# > ---
# >
# > **<font size=4>学生信息与其数据对应关系：</font>**
#
# | 姓名 | 语文 | 英语 | 数学 |
# | --- | --- | --- | --- |
# | 王刚 | 110 | 140 | 120 |
# > **<font size=4>代码：</font>**
# > ```python
# > stu1={
# >     '姓名': '王刚',
# >     '语文': 110,
# >     '英语': 140,
# >     '数学': 120,
# > }
# > ```
# >
# > ---
# > **<font size=4>学号与学生的对应关系：</font>**
#
# | 学号 |
# | --- |
# | 学生信息 |
#
# > **<font size=4>代码：</font>**
# > ```python
# > info = {
# >     '一班': {
# >         '01':{
# >             '姓名': '王刚',
# >             '语文': 110,
# >             '英语': 140,
# >             '数学': 120,
# >         }
# >         '02':{
# >             '姓名': '李磊',
# >             '语文': 142,
# >             '英语': 111,
# >             '数学': 105,
# >         }
# >         ...
# >     }
# >     '二班': {}
# > }
# > ```
# > <font size=3>直接运行下列代码，将数据和备用函数加载进内存：</font>

# %%
info = {
    '一班': 
    {
        '001': {'姓名': '刘梅', '语文': 63, '数学': 71, '英语': 76},
        '002': {'姓名': '孙玲', '语文': 83, '数学': 68, '英语': 76},
        '003': {'姓名': '梁斌', '语文': 76, '数学': 75, '英语': 76},
        '004': {'姓名': '郑淑华', '语文': 58, '数学': 81, '英语': 64},
        '005': {'姓名': '郑建国', '语文': 68, '数学': 90, '英语': 78},
        '006': {'姓名': '刘秀荣', '语文': 90, '数学': 71, '英语': 70},
        '007': {'姓名': '陈桂芳', '语文': 49, '数学': 82, '英语': 80},
        '008': {'姓名': '罗璐', '语文': 69, '数学': 78, '英语': 52},
        '009': {'姓名': '韩玉华', '语文': 86, '数学': 78, '英语': 59},
        '010': {'姓名': '谢刚', '语文': 65, '数学': 68, '英语': 77},
        '011': {'姓名': '董秀云', '语文': 67, '数学': 64, '英语': 92},
        '012': {'姓名': '王畅', '语文': 73, '数学': 62, '英语': 82},
        '013': {'姓名': '刘俊', '语文': 88, '数学': 66, '英语': 67},
        '014': {'姓名': '曹华', '语文': 67, '数学': 77, '英语': 57},
        '015': {'姓名': '董莉', '语文': 69, '数学': 81, '英语': 81},
        '016': {'姓名': '刘红', '语文': 69, '数学': 77, '英语': 73},
        '017': {'姓名': '秦杰', '语文': 96, '数学': 68, '英语': 79},
        '018': {'姓名': '张红霞', '语文': 95, '数学': 92, '英语': 75},
        '019': {'姓名': '葛玉', '语文': 84, '数学': 89, '英语': 74},
        '020': {'姓名': '胡秀英', '语文': 77, '数学': 70, '英语': 103},
        '021': {'姓名': '彭阳', '语文': 81, '数学': 65, '英语': 73},
        '022': {'姓名': '白桂芳', '语文': 88, '数学': 75, '英语': 72},
        '023': {'姓名': '石勇', '语文': 64, '数学': 86, '英语': 72},
        '024': {'姓名': '王文', '语文': 85, '数学': 77, '英语': 68},
        '110': {'姓名': '曾红', '语文': 57, '数学': 75, '英语': 91},
        '111': {'姓名': '任欣', '语文': 69, '数学': 57, '英语': 70},
        '112': {'姓名': '夏雪梅', '语文': 86, '数学': 81, '英语': 72},
        '113': {'姓名': '沈东', '语文': 66, '数学': 71, '英语': 64},
        '114': {'姓名': '庞晨', '语文': 79, '数学': 74, '英语': 64},
        '115': {'姓名': '丁娜', '语文': 84, '数学': 77, '英语': 61},
        '116': {'姓名': '杨玉华', '语文': 76, '数学': 69, '英语': 70},
        '117': {'姓名': '傅刚', '语文': 60, '数学': 84, '英语': 64},
        '118': {'姓名': '王金凤', '语文': 70, '数学': 72, '英语': 94},
        '119': {'姓名': '沈荣', '语文': 93, '数学': 79, '英语': 55},
        '120': {'姓名': '彭涛', '语文': 53, '数学': 72, '英语': 62}
    }
}

# 检查学生信息字段的规则
# 不符合规则：返回True  符合规则：返回False
def check_fields(stu_info):
    if list(stu_info.keys()) != ["姓名", "语文", "数学", "英语"]:
        print("学生信息中的字段必须为 ‘姓名’，‘语文’，‘数学’，‘英语’")
        return True
    elif type(stu_info["姓名"]) != str:
        print("姓名信息需要为字符串类型")
        return True
    elif type(stu_info["语文"]) != int or type(stu_info["数学"]) != int or type(stu_info["英语"]) != int:
        print("分数需要为整数类型")
        return True
    elif check_score(stu_info["语文"]) or check_score(stu_info["数学"]) or check_score(stu_info["英语"]):
        print("分数的范围必须在0-100之间")
        return True
    return False

# 检查分数是否在0-100的范围内
# 不在范围内：返回True  在范围内：返回False
def check_score(value):
    if value > 100 or value < 0:
        return True
    else:
        return False

# 检查学生是否存在
# 存在：返回True  不存在：返回False
def check_num(stu_num):
    class_names = ["一班", "二班"]
    for class_name in class_names:
        if stu_num in info[class_name].keys():
            return True
    return False

# 班级的判断
def check_class(class_name):
    if class_name == '一班' or class_name == '二班':
        return False
    return True

# 班级的判断
def judge(class_name):
    if class_name == '一班' or class_name == '二班':
        return False
    return True

# judge函数不需要修改，修改会使程序出错
def judge1(class_name,subject_name):
    if class_name == '一班' or class_name == '二班':
        if(subject_name == '语文' or subject_name == '数学' or subject_name == '英文'):
            return 0
    return 1

# %% [markdown]
# > ### 4、在指定班中添加一个学生的信息
# >
# > <font size=3>解析：使用函数在某个班里添加某个学生的信息</font>
# >
# > <font size=3>要求：使用函数创建</font>
# >
# > <font size=3>函数名：add_stu</font>
# >
# > <font size=3>传入参数：无</font>
# >
# > <font size=3>返回值：无</font>
# >
# > **<font size=4>代码：</font>**
# > ```python
# > def add_stu():
# >     函数体
# > ```

# %%
# 答题部分
# stu_num:作用获取用户输入的学号，这里要求必须为一个整型的数字，学号在1-120时会认为学生存在
# stu_info:为一个字典，存储学生信息
def add_stu():
    stu_num = （这里补充一个函数用于接收用户的输入，且需转换为整形，补充代码）
    class_name = input('请输入班级名称：')
    stu_name = input('请输入学生姓名：')
    stu_chinese = int(input('请输入学生语文成绩：'))
    stu_math = int(input('请输入学生数学成绩：'))
    stu_eng = int(input('请输入学生英语成绩：'))
    
    stu_info = （这里创建一个字典，对应关系分别为：姓名--stu_name，语文--stu_chinese，数学--stu_math，英语--stu_eng，）

    stu_num = str(stu_num).zfill(3)
    if check_num(stu_num):
        print("学生已存在")
    else:
        if not (check_fields(stu_info) or check_class(class_name)):
            info[class_name][stu_num] = stu_info
            print(info[class_name][stu_num]["姓名"]+"信息已添加")
        else:
            print("添加的学数据不符合字段要求")

# %% [markdown]
# > ### 5、删除指定班中的学生的信息
# >
# > <font size=3>解析：使用函数删除某个班里某个学生的信息</font>
# >
# > <font size=3>要求：使用函数创建</font>
# >
# > <font size=3>函数名：del_stu</font>
# >
# > <font size=3>传入参数：无</font>
# >
# > <font size=3>返回值：无</font>
# >
# > **<font size=4>代码：</font>**
# > ```python
# > def del_stu():
# >     函数体
# > ```

# %%
# stu_num:作用获取用户输入的学号，这里要求必须为一个整型的数字，学号在1-120时会认为学生存在
# info[class_name][stu_num]为读取到的学生的信息 

def del_stu():
    stu_num = （这里补充一个函数用于接收用户的输入，且需转换为整形，补充代码）
    class_name = input('请输入班级名称：')
    stu_num = str(stu_num).zfill(3)
    if not check_num(stu_num):
        print('学生不存在')
    else:
        if not jud(class_name):
            print(info[class_name][stu_num]['姓名']+'信息已删除')
            （这里使用del关键字删除info[class_name][stu_num]，完成代码）
        else:
            print('添加的班级或者数据不符合字段要求')

# %% [markdown]
# > ### 6、更新某个班中的学生的信息
# >
# > <font size=3>解析：使用函数更新某个班里某个学生的某个信息</font>
# >
# > <font size=3>要求：使用函数创建</font>
# >
# > <font size=3>函数名：updata_stu</font>
# >
# > <font size=3>传入参数：无</font>
# >
# > <font size=3>返回值：无</font>
# >
# > **<font size=4>代码：</font>**
# > ```python
# > def updata_stu():
# >     函数体
# > ```

# %%
# stu_num:作用获取用户输入的学号，这里要求必须为一个整型的数字，学号在1-120时会认为学生存在
# fields:为存储各个属性的列表，用于后面判断是否存在需要修改的属性

def updata_stu():
    stu_num = （这里补充一个函数用于接收用户的输入，且需转换为整形，补充代码）
    class_name = input('请输入班级名称：')
    field = input('请输入需要修改的属性：')
    value = int(input('请输入需要更新的分数：'))
    
    fields = （创建一个有 姓名、语文、数学、英语 的列表）
    
    stu_num = str(stu_num).zfill(3)
    if not judge(class_name):
        if stu_num in info[class_name].keys():
            if field in fields:
                if field == fields[0] and type(value) != str:
                    print("姓名信息需要为字符串类型")
                elif (field in fields[1:]) and type(value) != int:
                    print(field+"分数需要为整数类型")
                elif (field in fields[1:])  and check_score(value) :
                    print(field+"分数的范围必须在0-100之间")
                else:
                    name = info[class_name][stu_num]["姓名"]
                    info[class_name][stu_num][field] = value
                    print(name+"的"+field+"已更新为"+str(value))
            else:
                print("要进行更新的字段不存在")
        else:
            print("学生不在相应班级或学生不存在")
    else:
        print("班级输入错误")

# %% [markdown]
# > ### 7、返回指定班某科的平均值
# >
# > <font size=3>解析：使用函数返回某个班某科的平均值</font>
# >
# > <font size=3>要求：使用函数创建</font>
# >
# > <font size=3>函数名：return_ave</font>
# >
# > <font size=3>传入参数：无</font>
# >
# > <font size=3>返回值：无</font>
# >
# > **<font size=4>代码：</font>**
# > ```python
# > def return_ave():
# >     函数体
# > ```
# > ---
# >
# > **<font size=4>示例：</font>**
# >
# > <font size=3>请输入班级名称：二班</font>
# >
# > <font size=3>请输入科目名称：语文</font>
# >
# > <font size=3>输出：二班的语文考试成绩为72.87分</font>
# >
# >
# > <font size=3>请完善return_ave函数中的代码：</font>

# %%
# class_name: 接收用户输入的班级
# subject_name: 接收用户输入的科目
# count: 存储分数的总和
# ave: 存储计算出来的平均分

def return_ave():
    class_name = （此行代码作用为接收用户输入班级名称，赋值给class_name，请完善代码）
    subject_name = （此行代码作用为接收用户输入科目名称，赋值给subject_name，请完善代码）
    jud = judge1(class_name,subject_name) # 此处jud作为判断输入是否合法，jud为0时，程序正常运行，为1时提示输入错误
    
    if(jud==0):   
        count = 0
        for i in list(info[class_name].keys()):   # 遍历某班所有同学的学号
            count+=（此行代码为通过遍历的学号，获取到每个学生的某科成绩，并加到count中，等同于求和）
        ave = （此行代码为计算平均值，通过获取到的总体成绩count，除以此班人数，赋值给ave）
        ave = class_name + '的' + subject_name + '考试成绩为' + str(ave) + '分'
    else:
        ave = '用户输入不合法，请重新选择功能'
    return print(ave)

# 测试函数
return_ave()

# %% [markdown]
# > ### 8、画出两个班级三科总分的平均值柱状图
# >
# > <font size=3>解析：使用函数画出班级三科总分的平均值柱状图</font>
# >
# > <font size=3>要求：使用函数与pyecharts结合</font>
# >
# > <font size=3>函数名：paint_ave</font>
# >
# > <font size=3>传入参数：无</font>
# >
# > <font size=3>返回值：bar.render('bar.html')</font>
# >
# > **<font size=4>代码：</font>**
# > ```python
# > def paint_ave():
# >     函数体
# > ```
# >
# >
# > <font size=3>请完善paint_ave函数中的代码：</font>

# %%
from pyecharts.charts import Bar

# chinese:存储遍历到的每个学生的语文成绩
# math:存储遍历到的每个学生的数学成绩
# eng:存储遍历到的每个学生的英语成绩
# class_list:分别存储每个班所有学生的总分
# scores_list:存储两个班总成绩的均值 的列表

def paint_ave():
    class_list = {'一班': 0, '二班':0}
    for i in list(info.keys()):
        for j in list(info[i].keys()):
            chinese = （存储遍历到的每个学生的语文成绩，请完善代码）
            math = （存储遍历到的每个学生的数学成绩，请完善代码）
            eng = （存储遍历到的每个学生的英语成绩，请完善代码）
            class_list[i] += chinese + math + eng
        class_list[i] = class_list[i]/len(list(info[i].keys()))
        
    scores_list = （存储两个班总成绩的均值的列表，值是从class_list中取出，请完善代码）
    bar = Bar()
    bar.add_xaxis(['一班','二班'])
    bar.add_yaxis("总分平均分", scores_list, bar_width='40')
    return bar.render('bar.html')

# 测试函数
paint_ave()

# %% [markdown]
# > ### 9、整合代码
# >
# > <font size=3>解析：将完成的代码函数，整合到整体程序结构中</font>
# >
# > <font size=3>按照choose对应的1、2、3、4、5，将对应功能的函数放到判断choose的if分支中即可</font>
# >
# > **<font size=4>示例代码：</font>**
# > ```python
# >   while True:
# >       print('1.添加一个学生的信息')
# >       print('2.删除一个学生的信息')
# >       print('3.更新一个学生的信息')
# >       print('4.返回指定班某科的平均值')
# >       print('5.输出两个班级三科总分的平均值柱状图')
# >       choose = （此处补充input函数，传入参数为：'请输入1到5的一个数字'）
# >       if choose == '1':
# >           add_stu()
# >       elif choose == '2':
# >           del_stu()
# >       （我们会判断输入分别为1、2、3、4、5时程序的运行，此处将剩余用户输入判断完成）
# >       else:
# >           print('输入错误，返回主界面')
# >       if(require() == 0):
# >               break
# > ```
# >
# >
# > <font size=3>请将已完成的第2题的代码拷贝到下面代码块中并完成上述要求</font>
